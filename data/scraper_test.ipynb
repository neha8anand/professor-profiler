# %%
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# # Scraping usnews for a given engineering major's top universities
# * We scrape four fields: Name, Location, Score and Ranking(interpreted from Score).
# * Combine these four fields to form a list
# * Store results in a json file with the following structure:
# {major_name1: {university_name1: {location:, score:, rank:}}}

# %%
majors = ['aerospace', 'biological-agricultural', 'biomedical','chemical-engineering', 
          'civil-engineering', 'computer-engineering','electrical-engineering', 
          'environmental-engineering', 'industrial-engineering','material-engineering', 
          'mechanical-engineering', 'nuclear-engineering', 'petroleum engineering']

# %%
url = "https://www.usnews.com/best-graduate-schools/search?program=top-engineering-schools&name=&specialty=petroleum-engineering"
# Find user agent in headers in network in Chrome developer tools
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Names of universities
universities = []
for a_tag in soup.select("a.Anchor-s8bzdzo-0.fwxkXI"):
    universities.append(a_tag.get_text())

# locations
locations = []
for p_tag in soup.select("p.Paragraph-fqygwe-0.cPvbgl"):
    locations.append(p_tag.get_text())


# scores
scores = []
for p_tag in soup.select("p.fqygwe-0-Paragraph-hHEPzZ.kkoztb"):
    if p_tag.get_text() != 'N/A':
        scores.append(float(p_tag.get_text()))

# ranks (recreated from scores)
ranks = create_ranks(scores)

# %%
print(len(universities), len(locations), len(scores), len(ranks))
# Out:
# 26 14 12 12

# %%
universities[:12]
# Out:
# ['University of Texas--Austin (Cockrell)',
#  'Stanford University',
#  'Texas A&M University--College Station',
#  'University of Tulsa',
#  'Colorado School of Mines',
#  'Pennsylvania State University--University Park',
#  'University of Oklahoma',
#  'University of Southern California (Viterbi)',
#  'Louisiana State University--Baton Rouge',
#  'Texas Tech University (Whitacre)',
#  'University of Kansas',
#  'University of Wyoming']

# %%
def create_ranks(scores):
    '''
    Creates ranks corresponding to the scores, allowing for ties between universities.
    '''
    ranks = list(range(1, len(scores) + 1))    
    # Allowing for ties
    for i, score in enumerate(scores[1:], start=1):
        if score == scores[i - 1]:
            ranks[i] = ranks[i-1] 
    return ranks

# %%
# final_code
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'} 

results = {}

for major in majors:
    results[major] = {}
    
    url = "https://www.usnews.com/best-graduate-schools/search?program=top-engineering-schools&name=&specialty=" + major
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Names of universities
    universities = []
    for a_tag in soup.select("a.Anchor-s8bzdzo-0.fwxkXI"):
        universities.append(a_tag.get_text())
    
    # locations
    locations = []
    for p_tag in soup.select("p.Paragraph-fqygwe-0.cPvbgl"):
        locations.append(p_tag.get_text())
    
    # scores
    scores = []
    for p_tag in soup.select("p.fqygwe-0-Paragraph-hHEPzZ.kkoztb"):
        if p_tag.get_text() != 'N/A':
            scores.append(float(p_tag.get_text()))
    
    # ranks (recreated from scores)
    ranks = create_ranks(scores)
    
    # Dropping universities with empty scores
    universities = universities[:len(scores)]
    locations = locations[:len(scores)]
    
    # Storing results
    for university, location, score, rank in zip(universities, locations, scores, ranks):
        results[major][university] = {'location': location, 'score' : score, 'rank': rank}
# Out:
# {'aerospace': {'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.7,
#    'rank': 1},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.7,
#    'rank': 1},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.6, 'rank': 3},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.5,
#    'rank': 4},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.4,
#    'rank': 5},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.2,
#    'rank': 6},
#   'Texas A&M University--College Station': {'location': 'College Station, TX',
#    'score': 4.0,
#    'rank': 7},
#   'Princeton University': {'location': 'Princeton, NJ',
#    'score': 3.9,
#    'rank': 8},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 3.9,
#    'rank': 8},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 3.9,
#    'rank': 8},
#   'Virginia Tech': {'location': 'Blacksburg, VA', 'score': 3.8, 'rank': 11},
#   'University of Colorado--Boulder': {'location': 'Boulder, CO',
#    'score': 3.7,
#    'rank': 12},
#   'University of Maryland--College Park (Clark)': {'location': 'College Park, MD',
#    'score': 3.7,
#    'rank': 12}},
#  'biological-agricultural': {'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.8,
#    'rank': 1},
#   'Iowa State University': {'location': 'Ames, IA', 'score': 4.6, 'rank': 2},
#   'Texas A&M University--College Station': {'location': 'College Station, TX',
#    'score': 4.3,
#    'rank': 3},
#   'University of Florida': {'location': 'Gainesville, FL',
#    'score': 4.1,
#    'rank': 4},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 4.0, 'rank': 5},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.0,
#    'rank': 5},
#   'University of California--Davis': {'location': 'Davis, CA',
#    'score': 3.9,
#    'rank': 7},
#   'North Carolina State University': {'location': 'Raleigh, NC',
#    'score': 3.8,
#    'rank': 8},
#   'Pennsylvania State University--University Park': {'location': 'University Park, PA',
#    'score': 3.8,
#    'rank': 8},
#   'University of Nebraska--Lincoln': {'location': 'Lincoln, NE',
#    'score': 3.7,
#    'rank': 10},
#   'Michigan State University': {'location': 'East Lansing, MI',
#    'score': 3.6,
#    'rank': 11},
#   'Ohio State University': {'location': 'Columbus, OH',
#    'score': 3.6,
#    'rank': 11},
#   'Virginia Tech': {'location': 'Blacksburg, VA', 'score': 3.6, 'rank': 11}},
#  'biomedical': {'Johns Hopkins University (Whiting)': {'location': 'Baltimore, MD',
#    'score': 4.6,
#    'rank': 1},
#   'Emory University-Georgia Tech University': {'location': 'null, GA',
#    'score': 4.5,
#    'rank': 2},
#   'University of California--San Diego (Jacobs)': {'location': 'La Jolla, CA',
#    'score': 4.5,
#    'rank': 2},
#   'Duke University (Pratt)': {'location': 'Durham, NC',
#    'score': 4.4,
#    'rank': 4},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.4,
#    'rank': 4},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.4, 'rank': 4},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.4,
#    'rank': 4},
#   'University of Pennsylvania': {'location': 'Philadelphia, PA',
#    'score': 4.4,
#    'rank': 4},
#   'Rice University (Brown)': {'location': 'Houston, TX',
#    'score': 4.1,
#    'rank': 9},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.1,
#    'rank': 9},
#   'University of Washington': {'location': 'Seattle, WA',
#    'score': 4.1,
#    'rank': 9},
#   'Boston University': {'location': 'Boston, MA', 'score': 4.0, 'rank': 12},
#   'Columbia University (Fu Foundation)': {'location': 'New York, NY',
#    'score': 4.0,
#    'rank': 12}},
#  'chemical-engineering': {'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.8,
#    'rank': 1},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.6,
#    'rank': 2},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.6, 'rank': 2},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.6,
#    'rank': 2},
#   'University of Minnesota--Twin Cities': {'location': 'Minneapolis, MN',
#    'score': 4.5,
#    'rank': 5},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.4,
#    'rank': 6},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.3,
#    'rank': 7},
#   'University of Wisconsin--Madison': {'location': 'Madison, WI',
#    'score': 4.3,
#    'rank': 7},
#   'Princeton University': {'location': 'Princeton, NJ',
#    'score': 4.1,
#    'rank': 9},
#   'University of Delaware': {'location': 'Newark, DE',
#    'score': 4.1,
#    'rank': 9},
#   'University of California--Santa Barbara': {'location': 'Santa Barbara, CA',
#    'score': 4.0,
#    'rank': 11},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.0,
#    'rank': 11}},
#  'civil-engineering': {'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.7,
#    'rank': 1},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.5,
#    'rank': 2},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.5, 'rank': 2},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.5,
#    'rank': 2},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.5,
#    'rank': 2},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.2,
#    'rank': 6},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.1,
#    'rank': 7},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.1,
#    'rank': 7},
#   'Virginia Tech': {'location': 'Blacksburg, VA', 'score': 4.1, 'rank': 7},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 3.9,
#    'rank': 10},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 3.8,
#    'rank': 11},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 3.8, 'rank': 11},
#   'Northwestern University (McCormick)': {'location': 'Evanston, IL',
#    'score': 3.8,
#    'rank': 11},
#   'University of California--Davis': {'location': 'Davis, CA',
#    'score': 3.8,
#    'rank': 11}},
#  'computer-engineering': {'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.9,
#    'rank': 1},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.8,
#    'rank': 2},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.7,
#    'rank': 3},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 4.6,
#    'rank': 4},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.6,
#    'rank': 4},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.5,
#    'rank': 6},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.3,
#    'rank': 7},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.3,
#    'rank': 7},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 4.2, 'rank': 9},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.2,
#    'rank': 9},
#   'University of Washington': {'location': 'Seattle, WA',
#    'score': 4.2,
#    'rank': 9},
#   'Princeton University': {'location': 'Princeton, NJ',
#    'score': 4.1,
#    'rank': 12}},
#  'electrical-engineering': {'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.9,
#    'rank': 1},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.9, 'rank': 1},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.9,
#    'rank': 1},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.8,
#    'rank': 4},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.6,
#    'rank': 5},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.6,
#    'rank': 5},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.5,
#    'rank': 7},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 4.4,
#    'rank': 8},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 4.3, 'rank': 9},
#   'Princeton University': {'location': 'Princeton, NJ',
#    'score': 4.3,
#    'rank': 9},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.3,
#    'rank': 9},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.3,
#    'rank': 9}},
#  'environmental-engineering': {'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.6,
#    'rank': 1},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.4, 'rank': 2},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.2,
#    'rank': 3},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.2,
#    'rank': 3},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.1,
#    'rank': 5},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.0,
#    'rank': 6},
#   'Virginia Tech': {'location': 'Blacksburg, VA', 'score': 4.0, 'rank': 6},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 3.9,
#    'rank': 8},
#   'Yale University': {'location': 'New Haven, CT', 'score': 3.8, 'rank': 9},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 3.7, 'rank': 10},
#   'Duke University (Pratt)': {'location': 'Durham, NC',
#    'score': 3.6,
#    'rank': 11},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 3.6,
#    'rank': 11}},
#  'industrial-engineering': {'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.8,
#    'rank': 1},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.6,
#    'rank': 2},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.4,
#    'rank': 3},
#   'Northwestern University (McCormick)': {'location': 'Evanston, IL',
#    'score': 4.3,
#    'rank': 4},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 4.2, 'rank': 5},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.1,
#    'rank': 6},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.0,
#    'rank': 7},
#   'Pennsylvania State University--University Park': {'location': 'University Park, PA',
#    'score': 4.0,
#    'rank': 7},
#   'University of Wisconsin--Madison': {'location': 'Madison, WI',
#    'score': 4.0,
#    'rank': 7},
#   'Virginia Tech': {'location': 'Blacksburg, VA', 'score': 4.0, 'rank': 7},
#   'Columbia University (Fu Foundation)': {'location': 'New York, NY',
#    'score': 3.9,
#    'rank': 11},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 3.8,
#    'rank': 12}},
#  'material-engineering': {'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.9,
#    'rank': 1},
#   'Northwestern University (McCormick)': {'location': 'Evanston, IL',
#    'score': 4.7,
#    'rank': 2},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.5, 'rank': 3},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.5,
#    'rank': 3},
#   'University of California--Santa Barbara': {'location': 'Santa Barbara, CA',
#    'score': 4.4,
#    'rank': 5},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.3,
#    'rank': 6},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.2,
#    'rank': 7},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.2,
#    'rank': 7},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.0,
#    'rank': 9},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 3.9, 'rank': 10},
#   'Harvard University': {'location': 'Cambridge, MA',
#    'score': 3.8,
#    'rank': 11},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 3.7,
#    'rank': 12},
#   'Pennsylvania State University--University Park': {'location': 'University Park, PA',
#    'score': 3.7,
#    'rank': 12}},
#  'mechanical-engineering': {'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.9,
#    'rank': 1},
#   'Stanford University': {'location': 'Stanford, CA', 'score': 4.8, 'rank': 2},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 4.7,
#    'rank': 3},
#   'California Institute of Technology': {'location': 'Pasadena, CA',
#    'score': 4.6,
#    'rank': 4},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 4.5,
#    'rank': 5},
#   'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.5,
#    'rank': 5},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 4.3,
#    'rank': 7},
#   'Princeton University': {'location': 'Princeton, NJ',
#    'score': 4.1,
#    'rank': 8},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 4.1,
#    'rank': 8},
#   'Carnegie Mellon University': {'location': 'Pittsburgh, PA',
#    'score': 4.0,
#    'rank': 10},
#   'Cornell University': {'location': 'Ithaca, NY', 'score': 4.0, 'rank': 10},
#   'University of Texas--Austin (Cockrell)': {'location': 'Austin, TX',
#    'score': 4.0,
#    'rank': 10}},
#  'nuclear-engineering': {'University of Michigan--Ann Arbor': {'location': 'Ann Arbor, MI',
#    'score': 4.7,
#    'rank': 1},
#   'Massachusetts Institute of Technology': {'location': 'Cambridge, MA',
#    'score': 4.3,
#    'rank': 2},
#   'Texas A&M University--College Station': {'location': 'College Station, TX',
#    'score': 4.0,
#    'rank': 3},
#   'North Carolina State University': {'location': 'Raleigh, NC',
#    'score': 3.9,
#    'rank': 4},
#   'University of California--Berkeley': {'location': 'Berkeley, CA',
#    'score': 3.8,
#    'rank': 5},
#   'University of Illinois--Urbana-Champaign': {'location': 'Urbana, IL',
#    'score': 3.8,
#    'rank': 5},
#   'University of Wisconsin--Madison': {'location': 'Madison, WI',
#    'score': 3.8,
#    'rank': 5},
#   'University of Tennessee--Knoxville (Tickle)': {'location': 'Knoxville, TN',
#    'score': 3.6,
#    'rank': 8},
#   'Georgia Institute of Technology': {'location': 'Atlanta, GA',
#    'score': 3.5,
#    'rank': 9},
#   'Pennsylvania State University--University Park': {'location': 'University Park, PA',
#    'score': 3.5,
#    'rank': 9},
#   'Oregon State University': {'location': 'Corvallis, OR',
#    'score': 3.3,
#    'rank': 11},
#   'Purdue University--West Lafayette': {'location': 'West Lafayette, IN',
#    'score': 3.3,
#    'rank': 11}},
#  'petroleum engineering': {}}

# %%
with open('usnews.json', 'w') as usnews:
    json.dump(results, usnews)
