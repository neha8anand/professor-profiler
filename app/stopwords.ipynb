# %%
from model import MyModel
import pickle

with open('../data/pge_model.pkl', 'rb') as f:
        model = pickle.load(f)

with open('../data/pge_vectorizer.pkl', 'rb') as f:
    vectorizer = pickle.load(f)

# %%
len(vectorizer.vocabulary_)
# Out:
# 15980

# %%
vocab = sorted(vectorizer.vocabulary_.items(), key=lambda x:x[1], reverse=True)

# %%
vocab
# Out:
# [('𝑠𝑠𝑣', 15979),
#  ('𝑠𝑠ℎ', 15978),
#  ('𝑠𝑝𝑣', 15977),
#  ('𝑠𝑝ℎ', 15976),
#  ('𝑐66', 15975),
#  ('𝑐44', 15974),
#  ('𝑐33', 15973),
#  ('𝑐13', 15972),
#  ('𝑐11', 15971),
#  ('ℓe', 15970),
#  ('φsw', 15969),
#  ('τy', 15968),
#  ('σwφswet', 15967),
#  ('σw', 15966),
#  ('σt', 15965),
#  ('σow', 15964),
#  ('σh', 15963),
#  ('σd', 15962),
#  ('σapp', 15961),
#  ('μs', 15960),
#  ('μm', 15959),
#  ('μd', 15958),
#  ('μct', 15957),
#  ('λc', 15956),
#  ('εr', 15955),
#  ('δ47', 15954),
#  ('δ18o', 15953),
#  ('δ13corg', 15952),
#  ('δ13c', 15951),
#  ('γl', 15950),
#  ('βl', 15949),
#  ('βe', 15948),
#  ('αl1', 15947),
#  ('å2', 15946),
#  ('ßq', 15945),
#  ('ºf', 15944),
#  ('ºc', 15943),
#  ('ºapi', 15942),
#  ('µw', 15941),
#  ('µo', 15940),
#  ('µm3', 15939),
#  ('µm', 15938),
#  ('µd', 15937),
#  ('zwitterionic', 15936),
#  ('zuo', 15935),
#  ('zp', 15934),
#  ('zou', 15933),
#  ('zones', 15932),
#  ('zoned', 15931),
#  ('zone', 15930),
#  ('zonal', 15929),
#  ('zoback', 15928),
#  ('zno', 15927),
#  ('zirconium', 15926),
#  ('zirconia', 15925),
#  ('zinc', 15924),
#  ('zimmer', 15923),
#  ('ziegler', 15922),
#  ('zhu', 15921),
#  ('zhou', 15920),
#  ('zheng', 15919),
#  ('zheltov', 15918),
#  ('zhao', 15917),
#  ('zhanget', 15916),
#  ('zhang', 15915),
#  ('zhai', 15914),
#  ('zetasizer', 15913),
#  ('zeta', 15912),
#  ('zerón', 15911),
#  ('zero', 15910),
#  ('zerhboub', 15909),
#  ('zeolite', 15908),
#  ('zellerfeld', 15907),
#  ('zeiss', 15906),
#  ('zebra', 15905),
#  ('zealand', 15904),
#  ('zaykina', 15903),
#  ('zaykin', 15902),
#  ('zahid', 15901),
#  ('yu', 15900),
#  ('yrs', 15899),
#  ('yr', 15898),
#  ('ypl', 15897),
#  ('ypf', 15896),
#  ('yousef', 15895),
#  ('younger', 15894),
#  ('young', 15893),
#  ('yortsos', 15892),
#  ('york', 15891),
#  ('yodavich', 15890),
#  ('ym', 15889),
#  ('ylimino', 15888),
#  ('yin', 15887),
#  ('yildiz', 15886),
#  ('yields15', 15885),
#  ('yields', 15884),
#  ('yielding', 15883),
#  ('yielded', 15882),
#  ('yield', 15881),
#  ('yet', 15880),
#  ('yellow', 15879),
#  ('years', 15878),
#  ('yearly', 15877),
#  ('year', 15876),
#  ('yardsticks', 15875),
#  ('yaojia', 15874),
#  ('yang', 15873),
#  ('yami', 15872),
#  ('yaich', 15871),
#  ('xylene', 15870),
#  ('xwl', 15869),
#  ('xutao', 15868),
#  ('xu', 15867),
#  ('xsledge', 15866),
#  ('xrf', 15865),
#  ('xrd', 15864),
#  ('xps', 15863),
#  ('xml', 15862),
#  ('xiu', 15861),
#  ('xiong', 15860),
#  ('xinjiang', 15859),
#  ('xil', 15858),
#  ('xie', 15857),
#  ('xi', 15856),
#  ('xgboost', 15855),
#  ('xfrac', 15854),
#  ('xfem', 15853),
#  ('xeon', 15852),
#  ('xenon', 15851),
#  ('xcuxal', 15850),
#  ('xcite', 15849),
#  ('xc', 15848),
#  ('xb120', 15847),
#  ('xanthan', 15846),
#  ('x90', 15845),
#  ('x0', 15844),
#  ('wyoming', 15843),
#  ('wyllie', 15842),
#  ('wylde', 15841),
#  ('wy', 15840),
#  ('www', 15839),
#  ('wwp', 15838),
#  ('wu', 15837),
#  ('wti', 15836),
#  ('wt', 15835),
#  ('wsms', 15834),
#  ('wsa', 15833),
#  ('ws', 15832),
#  ('wrote', 15831),
#  ('wrongly', 15830),
#  ('wrong', 15829),
#  ('written', 15828),
#  ('writing', 15827),
#  ('writers', 15826),
#  ('writer', 15825),
#  ('write', 15824),
#  ('wrinkles', 15823),
#  ('wright', 15822),
#  ('wrapped', 15821),
#  ('wpo', 15820),
#  ('wpd', 15819),
#  ('wpc', 15818),
#  ('would', 15817),
#  ('worthy', 15816),
#  ('worthwhile', 15815),
#  ('worth', 15814),
#  ('worst', 15813),
#  ('worsening', 15812),
#  ('worse', 15811),
#  ('wors', 15810),
#  ('wormlike', 15809),
#  ('wormholing', 15808),
#  ('wormholes', 15807),
#  ('wormhole', 15806),
#  ('worm', 15805),
#  ('worldwideworker', 15804),
#  ('worldwide', 15803),
#  ('world', 15802),
#  ('workstring', 15801),
#  ('workshop', 15800),
#  ('worksheets', 15799),
#  ('worksheet', 15798),
#  ('works', 15797),
#  ('workovers', 15796),
#  ('workover', 15795),
#  ('workload', 15794),
#  ('workings', 15793),
#  ('working', 15792),
#  ('workhorse', 15791),
#  ('workforce', 15790),
#  ('workflows', 15789),
#  ('workflow', 15788),
#  ('workers', 15787),
#  ('worker', 15786),
#  ('worked', 15785),
#  ('workboat', 15784),
#  ('workable', 15783),
#  ('work', 15782),
#  ('words', 15781),
#  ('wording', 15780),
#  ('word', 15779),
#  ('wor', 15778),
#  ('wooley', 15777),
#  ('woodford', 15776),
#  ('wooden', 15775),
#  ('wong', 15774),
#  ('wondering', 15773),
#  ('wonder', 15772),
#  ('wolthers', 15771),
#  ('wolfcamp', 15770),
#  ('woc', 15769),
#  ('wob', 15768),
#  ('wnss', 15767),
#  ('wns', 15766),
#  ('wlm', 15765),
#  ('wl', 15764),
#  ('witsmltm', 15763),
#  ('witsml', 15762),
#  ('wits', 15761),
#  ('witnessed', 15760),
#  ('withy', 15759),
#  ('withtime', 15758),
#  ('withstand', 15757),
#  ('without', 15756),
#  ('withmultiple', 15755),
#  ('withinitial', 15754),
#  ('withina', 15753),
#  ('within', 15752),
#  ('withgel', 15751),
#  ('withequivalent', 15750),
#  ('withdrawn', 15749),
#  ('withdifferent', 15748),
#  ('wish', 15747),
#  ('wise', 15746),
#  ('wisdom', 15745),
#  ('wis', 15744),
#  ('wireline', 15743),
#  ('wirelessly', 15742),
#  ('wired', 15741),
#  ('wire', 15740),
#  ('winterset', 15739),
#  ('winsauer', 15738),
#  ('winprop', 15737),
#  ('winning', 15736),
#  ('winland', 15735),
#  ('wings', 15734),
#  ('wing', 15733),
#  ('windy', 15732),
#  ('windup', 15731),
#  ('windsor', 15730),
#  ('windows', 15729),
#  ('windowing', 15728),
#  ('window', 15727),
#  ('winding', 15726),
#  ('wind', 15725),
#  ('win', 15724),
#  ('wim', 15723),
#  ('wilson', 15722),
#  ('williston', 15721),
#  ('willis', 15720),
#  ('williford', 15719),
#  ('williams', 15718),
#  ('william', 15717),
#  ('wildlife', 15716),
#  ('wiener', 15715),
#  ('widths', 15714),
#  ('widthrestriction', 15713),
#  ('width', 15712),
#  ('widespread', 15711),
#  ('wider', 15710),
#  ('widening', 15709),
#  ('widen', 15708),
#  ('widely', 15707),
#  ('wide', 15706),
#  ('wib', 15705),
#  ('wi', 15704),
#  ('wht', 15703),
#  ('whr', 15702),
#  ('whp', 15701),
#  ('whose', 15700),
#  ('whole', 15699),
#  ('whitson', 15698),
#  ('whitfield', 15697),
#  ('white', 15696),
#  ('whirl', 15695),
#  ('whilst', 15694),
#  ('whiledrilling', 15693),
#  ('whether', 15692),
#  ('wherein', 15691),
#  ('whereby', 15690),
#  ('whereas', 15689),
#  ('whenever', 15688),
#  ('wheeler', 15687),
#  ('wheaton', 15686),
#  ('whatsoever', 15685),
#  ('whatever', 15684),
#  ('wgs', 15683),
#  ('wft', 15682),
#  ('wfs', 15681),
#  ('wf', 15680),
#  ('weyl', 15679),
#  ('wetting', 15678),
#  ('wetter', 15677),
#  ('wetted', 15676),
#  ('wettability', 15675),
#  ('wetness', 15674),
#  ('wet', 15673),
#  ('western', 15672),
#  ('westermark', 15671),
#  ('westerly', 15670),
#  ('westerlies', 15669),
#  ('westergaard', 15668),
#  ('west', 15667),
#  ('wereperformed', 15666),
#  ('went', 15665),
#  ('weng', 15664),
#  ('welltest', 15663),
#  ('wellsuited', 15662),
#  ('wellsites', 15661),
#  ('wellsite', 15660),
#  ('wells', 15659),
#  ('wellpath', 15658),
#  ('wellpad', 15657),
#  ('welllog', 15656),
#  ('wellington', 15655),
#  ('wellhead', 15654),
#  ('welldocumented', 15653),
#  ('wellbores', 15652),
#  ('wellboreframe', 15651),
#  ('wellbore', 15650),
#  ('wellblock', 15649),
#  ('well', 15648),
#  ('welge', 15647),
#  ('welded', 15646),
#  ('weisrock', 15645),
#  ('weisbach', 15644),
#  ('weinaug', 15643),
#  ('weijermars', 15642),
#  ('weijdema', 15641),
#  ('weights', 15640),
#  ('weightings', 15639),
#  ('weighting', 15638),
#  ('weighted', 15637),
#  ('weight', 15636),
#  ('weighing', 15635),
#  ('wei', 15634),
#  ('wehrenberg', 15633),
#  ('wegner', 15632),
#  ('weeks', 15631),
#  ('week', 15630),
#  ('wedging', 15629),
#  ('webster', 15628),
#  ('website', 15627),
#  ('weber', 15626),
#  ('webb', 15625),
#  ('web', 15624),
#  ('weave', 15623),
#  ('weathering', 15622),
#  ('weathered', 15621),
#  ('weather', 15620),
#  ('wear', 15619),
#  ('wealth', 15618),
#  ('weaknesses', 15617),
#  ('weakness', 15616),
#  ('weakly', 15615),
#  ('weakest', 15614),
#  ('weaker', 15613),
#  ('weakens', 15612),
#  ('weakening', 15611),
#  ('weakened', 15610),
#  ('weak', 15609),
#  ('wcsb', 15608),
#  ('wci', 15607),
#  ('wcemit', 15606),
#  ('wcd', 15605),
#  ('wc2', 15604),
#  ('wbs', 15603),
#  ('wbm', 15602),
#  ('wbc', 15601),
#  ('ways', 15600),
#  ('way', 15599),
#  ('waxman', 15598),
#  ('waxing', 15597),
#  ('wax', 15596),
#  ('wavy', 15595),
#  ('waves', 15594),
#  ('wavelets', 15593),
#  ('wavelet', 15592),
#  ('wavelength', 15591),
#  ('waveforms', 15590),
#  ('waveform', 15589),
#  ('wave', 15588),
#  ('watts', 15587),
#  ('wattenbarger', 15586),
#  ('watson', 15585),
#  ('watertight', 15584),
#  ('waters', 15583),
#  ('waterless', 15582),
#  ('waterfront', 15581),
#  ('waterfloods', 15580),
#  ('waterflooding', 15579),
#  ('waterflooded', 15578),
#  ('waterflood', 15577),
#  ('watered', 15576),
#  ('watercut', 15575),
#  ('water', 15574),
#  ('wateflooding', 15573),
#  ('wasting', 15572),
#  ('wastewaters', 15571),
#  ('wastewater', 15570),
#  ('wastes', 15569),
#  ('wasted', 15568),
#  ('waste', 15567),
#  ('wasson', 15566),
#  ('washout', 15565),
#  ('washing', 15564),
#  ('washed', 15563),
#  ('wash', 15562),
#  ('wasachieved', 15561),
#  ('wars', 15560),
#  ('warrior', 15559),
#  ('warren', 15558),
#  ('warranted', 15557),
#  ('warrant', 15556),
#  ('warpinski', 15555),
#  ('warping', 15554),
#  ('warp', 15553),
#  ('warnings', 15552),
#  ('warn', 15551),
#  ('warms', 15550),
#  ('warming', 15549),
#  ('warmest', 15548),
#  ('warmer', 15547),
#  ('warmback', 15546),
#  ('warm', 15545),
#  ('wards', 15544),
#  ('ward', 15543),
#  ('wara', 15542),
#  ('wants', 15541),
#  ('wanted', 15540),
#  ('want', 15539),
#  ('waning', 15538),
#  ('wang', 15537),
#  ('wamsutter', 15536),
#  ('walters', 15535),
#  ('walter', 15534),
#  ('walsh', 15533),
#  ('walls', 15532),
#  ('wallis', 15531),
#  ('walled', 15530),
#  ('wallace', 15529),
#  ('wall', 15528),
#  ('walkup', 15527),
#  ('walkers', 15526),
#  ('walker', 15525),
#  ('walk', 15524),
#  ('wake', 15523),
#  ('waiting', 15522),
#  ('wait', 15521),
#  ('wagner', 15520),
#  ('wag', 15519),
#  ('wafer', 15518),
#  ('wacorg', 15517),
#  ('waco2', 15516),
#  ('wackestone', 15515),
#  ('waals', 15514),
#  ('wa', 15513),
#  ('vwµw', 15512),
#  ('vv', 15511),
#  ('vulnerable', 15510),
#  ('vulnerability', 15509),
#  ('vugular', 15508),
#  ('vugs', 15507),
#  ('vuggy', 15506),
#  ('vug', 15505),
#  ('vtk', 15504),
#  ('vti', 15503),
#  ('vs', 15502),
#  ('vrrs', 15501),
#  ('vrr', 15500),
#  ('vppd', 15499),
#  ('voytov', 15498),
#  ('voxels', 15497),
#  ('voxel', 15496),
#  ('voting', 15495),
#  ('voronoi', 15494),
#  ('voro', 15493),
#  ('voneiff', 15492),
#  ('von', 15491),
#  ('volz', 15490),
#  ('volumetrics', 15489),
#  ('volumetrically', 15488),
#  ('volumetric', 15487),
#  ('volumes', 15486),
#  ('volume', 15485),
#  ('volts', 15484),
#  ('voltec', 15483),
#  ('voltages', 15482),
#  ('voltage', 15481),
#  ('volt', 15480),
#  ('volga', 15479),
#  ('volcanism', 15478),
#  ('volcanic', 15477),
#  ('volatility', 15476),
#  ('volatile', 15475),
#  ('vol', 15474),
#  ('voir', 15473),
#  ('voinov', 15472),
#  ('voids', 15471),
#  ('voided', 15470),
#  ('voidage', 15469),
#  ('void', 15468),
#  ('voi', 15467),
#  ('vogd', 15466),
#  ('vof', 15465),
#  ('vocs', 15464),
#  ('vms', 15463),
#  ('vlle', 15462),
#  ('viz', 15461),
#  ('vivid', 15460),
#  ('vittoratos', 15459),
#  ('vitrinite', 15458),
#  ('vitally', 15457),
#  ('vital', 15456),
#  ('visuals', 15455),
#  ('visuallyrather', 15454),
#  ('visually', 15453),
#  ('visualizing', 15452),
#  ('visualizes', 15451),
#  ('visualized', 15450),
#  ('visualize', 15449),
#  ('visualizations', 15448),
#  ('visualization', 15447),
#  ('visual', 15446),
#  ('visited', 15445),
#  ('vision', 15444),
#  ('visible', 15443),
#  ('viscous', 15442),
#  ('viscosity', 15441),
#  ('viscosities', 15440),
#  ('viscosifying', 15439),
#  ('viscosify', 15438),
#  ('viscosifier', 15437),
#  ('viscosified', 15436),
#  ('viscosification', 15435),
#  ('viscoplastic', 15434),
#  ('viscometers', 15433),
#  ('viscometer', 15432),
#  ('viscofying', 15431),
#  ('viscoelasticity', 15430),
#  ('viscoelastic', 15429),
#  ('visco', 15428),
#  ('visbroken', 15427),
#  ('visbreaking', 15426),
#  ('virtually', 15425),
#  ('virtual', 15424),
#  ('virginia', 15423),
#  ('virgin', 15422),
#  ('vip', 15421),
#  ('violent', 15420),
#  ('violations', 15419),
#  ('vinylcaprolactam', 15418),
#  ('vinyl', 15417),
#  ('vintage', 15416),
#  ('vii', 15415),
#  ('vigorously', 15414),
#  ('vigorous', 15413),
#  ('vignes', 15412),
#  ('views', 15411),
#  ('viewpoints', 15410),
#  ('viewpoint', 15409),
#  ('viewing', 15408),
#  ('viewed', 15407),
#  ('view', 15406),
#  ('video', 15405),
#  ('vickers', 15404),
#  ('vicinity', 15403),
#  ('vicinities', 15402),
#  ('vice', 15401),
#  ('vibroseis', 15400),
#  ('vibrators', 15399),
#  ('vibrations', 15398),
#  ('vibrational', 15397),
#  ('vibration', 15396),
#  ('viable', 15395),
#  ('viability', 15394),
#  ('via', 15393),
#  ('vi', 15392),
#  ('vh', 15391),
#  ('vfsa', 15390),
#  ('vexing', 15389),
#  ('vessels', 15388),
#  ('vessel', 15387),
#  ('vess', 15386),
#  ('ves', 15385),
#  ('veryvaluable', 15384),
#  ('verwey', 15383),
#  ('vertices', 15382),
#  ('vertically', 15381),
#  ('vertical', 15380),
#  ('vertex', 15379),
#  ('versus', 15378),
#  ('versions', 15377),
#  ('version', 15376),
#  ('verses', 15375),
#  ('versatility', 15374),
#  ('versatile', 15373),
#  ('versa', 15372),
#  ('verma', 15371),
#  ('verifying', 15370),
#  ('verify', 15369),
#  ('verifies', 15368),
#  ('verified', 15367),
#  ('verification', 15366),
#  ('verifiable', 15365),
#  ('verhulst', 15364),
#  ('verdín', 15363),
#  ('veracity', 15362),
#  ('venturi', 15361),
#  ('ventures', 15360),
#  ('venture', 15359),
#  ('vented', 15358),
#  ('vensim', 15357),
#  ('vengosh', 15356),
#  ('venezuela', 15355),
#  ('venerable', 15354),
#  ('vendors', 15353),
#  ('vendor', 15352),
#  ('venant', 15351),
#  ('velocity', 15350),
#  ('velocities', 15349),
#  ('velocimetry', 15348),
#  ('veins', 15347),
#  ('vein', 15346),
#  ('vehicular', 15345),
#  ('vehicles', 15344),
#  ('vehicle', 15343),
#  ('vegetable', 15342),
#  ('vectors', 15341),
#  ('vectorized', 15340),
#  ('vector', 15339),
#  ('vdps', 15338),
#  ('vdp', 15337),
#  ('vdg', 15336),
#  ('vce', 15335),
#  ('vcap', 15334),
#  ('vba', 15333),
#  ('vastly', 15332),
#  ('vast', 15331),
#  ('vasquez', 15330),
#  ('vasco', 15329),
#  ('vasantharajan', 15328),
#  ('varyingeffective', 15327),
#  ('varying', 15326),
#  ('vary', 15325),
#  ('varotsis', 15324),
#  ('various', 15323),
#  ('variogram', 15322),
#  ('variety', 15321),
#  ('varieties', 15320),
#  ('varies', 15319),
#  ('varied', 15318),
#  ('variations', 15317),
#  ('variational', 15316),
#  ('variation', 15315),
#  ('variants', 15314),
#  ('variant', 15313),
#  ('variances', 15312),
#  ('variance', 15311),
#  ('variables', 15310),
#  ('variable', 15309),
#  ('variability', 15308),
#  ('variabilities', 15307),
#  ('varia', 15306),
#  ('vargo', 15305),
#  ('vargas', 15304),
#  ('vapour', 15303),
#  ('vaporizing', 15302),
#  ('vaporizes', 15301),
#  ('vaporized', 15300),
#  ('vaporize', 15299),
#  ('vaporization', 15298),
#  ('vapor', 15297),
#  ('vanorio', 15296),
#  ('vance', 15295),
#  ('vanadium', 15294),
#  ('van', 15293),
#  ('valves', 15292),
#  ('valve', 15291),
#  ('valuesare', 15290),
#  ('values', 15289),
#  ('valued', 15288),
#  ('value', 15287),
#  ('valuation', 15286),
#  ('valuable', 15285),
#  ('valleys', 15284),
#  ('valley', 15283),
#  ('vallecitos', 15282),
#  ('valkó', 15281),
#  ('valko', 15280),
#  ('validity', 15279),
#  ('validations', 15278),
#  ('validation', 15277),
#  ('validating', 15276),
#  ('validates', 15275),
#  ('validated', 15274),
#  ('validate', 15273),
#  ('valid', 15272),
#  ('valhall', 15271),
#  ('valency', 15270),
#  ('valdez', 15269),
#  ('vague', 15268),
#  ('vacuumed', 15267),
#  ('vacuum', 15266),
#  ('vaca', 15265),
#  ('v2', 15264),
#  ('v1', 15263),
#  ('uv', 15262),
#  ('utwell', 15261),
#  ('utpge', 15260),
#  ('utopian', 15259),
#  ('utomprs', 15258),
#  ('utnupro', 15257),
#  ('utmost', 15256),
#  ('utkr3p', 15255),
#  ('utilizing', 15254),
#  ('utilizes', 15253),
#  ('utilized', 15252),
#  ('utilize', 15251),
#  ('utilizations', 15250),
#  ('utilization', 15249),
#  ('utilizable', 15248),
#  ('utility', 15247),
#  ('utilities', 15246),
#  ('utica', 15245),
#  ('utgel', 15244),
#  ('utcomprs', 15243),
#  ('utcomp', 15242),
#  ('utchem', 15241),
#  ('utah25', 15240),
#  ('utah', 15239),
#  ('ut', 15238),
#  ('usually', 15237),
#  ('usual', 15236),
#  ('using', 15235),
#  ('usgs', 15234),
#  ('uses', 15233),
#  ('users', 15232),
#  ('user', 15231),
#  ('usefulness', 15230),
#  ('usefully', 15229),
#  ('useful', 15228),
#  ('used', 15227),
#  ('use', 15226),
#  ('usd', 15225),
#  ('usbm', 15224),
#  ('usage', 15223),
#  ('usable', 15222),
#  ('usability', 15221),
#  ('usa', 15220),
#  ('us', 15219),
#  ('uruguayan', 15218),
#  ('uruguay', 15217),
#  ('ursenbach', 15216),
#  ('ursa', 15215),
#  ('urs', 15214),
#  ('urr', 15213),
#  ('urges', 15212),
#  ('urgent', 15211),
#  ('ureteroscopy', 15210),
#  ('urea', 15209),
#  ('urbanization', 15208),
#  ('urban', 15207),
#  ('ural', 15206),
#  ('ur', 15205),
#  ('upwinding', 15204),
#  ('upwinded', 15203),
#  ('upwelling', 15202),
#  ('upwards', 15201),
#  ('upward', 15200),
#  ('upto', 15199),
#  ('uptakes', 15198),
#  ('uptake', 15197),
#  ('upstream', 15196),
#  ('upslope', 15195),
#  ('upside', 15194),
#  ('upsets', 15193),
#  ('upset', 15192),
#  ('upscaling', 15191),
#  ('upscalers', 15190),
#  ('upscaled', 15189),
#  ('upscale', 15188),
#  ('ups', 15187),
#  ('upper', 15186),
#  ('upon', 15185),
#  ('uplift', 15184),
#  ('uphole', 15183),
#  ('upgrading', 15182),
#  ('upgrades', 15181),
#  ('upgraded', 15180),
#  ('upgrade', 15179),
#  ('upfront', 15178),
#  ('updating', 15177),
#  ('updates', 15176),
#  ('updated', 15175),
#  ('update', 15174),
#  ('upcoming', 15173),
#  ('unzipping', 15172),
#  ('unweighted', 15171),
#  ('unwanted', 15170),
#  ('unvonentional', 15169),
#  ('unveiling', 15168),
#  ('unusual', 15167),
#  ('untreated', 15166),
#  ('untouched', 15165),
#  ('untapped', 15164),
#  ('unsymmetric', 15163),
#  ('unswept', 15162),
#  ('unsupervised', 15161),
#  ('unsuitable', 15160),
#  ('unsuccessful', 15159),
#  ('unstructured', 15158),
#  ('unstimulated', 15157),
#  ('unsteady', 15156),
#  ('unstable', 15155),
#  ('unsolved', 15154),
#  ('unsmooth', 15153),
#  ('unsettled', 15152),
#  ('unset', 15151),
#  ('unselective', 15150),
#  ('unseat', 15149),
#  ('unsaturated', 15148),
#  ('unsatisfactory', 15147),
#  ('unsafe', 15146),
#  ('unrocklike', 15145),
#  ('unrisked', 15144),
#  ('unretorted', 15143),
#  ('unrestricted', 15142),
#  ('unresolved', 15141),
#  ('unresolvable', 15140),
#  ('unreliable', 15139),
#  ('unrelated', 15138),
#  ('unrecovered', 15137),
#  ('unrecoverable', 15136),
#  ('unrecognized', 15135),
#  ('unreasonably', 15134),
#  ('unreasonable', 15133),
#  ('unrealistic', 15132),
#  ('unreacted', 15131),
#  ('unquestionably', 15130),
#  ('unprotonated', 15129),
#  ('unpropped', 15128),
#  ('unprofitable', 15127),
#  ('unproductive', 15126),
#  ('unpredictable', 15125),
#  ('unprecedented', 15124),
#  ('unplanned', 15123),
#  ('unperforated', 15122),
#  ('unobtainable', 15121),
#  ('unnoticed', 15120),
#  ('unnested', 15119),
#  ('unnecessary', 15118),
#  ('unnecessarily', 15117),
#  ('unmonitored', 15116),
#  ('unmodified', 15115),
#  ('unmineable', 15114),
#  ('unminable', 15113),
#  ('unmet', 15112),
#  ('unmeasured', 15111),
#  ('unmeasurable', 15110),
#  ('unmanageable', 15109),
#  ('unlocks', 15108),
#  ('unlocking', 15107),
#  ('unlocked', 15106),
#  ('unlock', 15105),
#  ('unloading', 15104),
#  ('unloaded', 15103),
#  ('unload', 15102),
#  ('unlikely', 15101),
#  ('unlike', 15100),
#  ('unless', 15099),
#  ('unknowns', 15098),
#  ('unknown', 15097),
#  ('unjammed', 15096),
#  ('university', 15095),
#  ('universities', 15094),
#  ('universally', 15093),
#  ('universal', 15092),
#  ('univariate', 15091),
#  ('unity', 15090),
#  ('units', 15089),
#  ('unitized', 15088),
#  ('united', 15087),
#  ('unitcells', 15086),
#  ('unit', 15085),
#  ('unisim', 15084),
#  ('uniqueness', 15083),
#  ('uniquely', 15082),
#  ('unique', 15081),
#  ('unintuitive', 15080),
#  ('uninterrupted', 15079),
#  ('unintentionally', 15078),
#  ('unintended', 15077),
#  ('unimportant', 15076),
#  ('unimodal', 15075),
#  ('unifying', 15074),
#  ('unify', 15073),
#  ('uniformly', 15072),
#  ('uniformity', 15071),
#  ('uniform', 15070),
#  ('unifies', 15069),
#  ('unified', 15068),
#  ('unidirectional', 15067),
#  ('unidentified', 15066),
#  ('unicellular', 15065),
#  ('uniaxial', 15064),
#  ('uni', 15063),
#  ('unhindered', 15062),
#  ('unheeded', 15061),
#  ('unfriendly', 15060),
#  ('unfractured', 15059),
#  ('unfortunately', 15058),
#  ('unforeseen', 15057),
#  ('unfiltered', 15056),
#  ('unfilled', 15055),
#  ('unfeasible', 15054),
#  ('unfavorable', 15053),
#  ('unfamiliarity', 15052),
#  ('unexplored', 15051),
#  ('unexpectedly', 15050),
#  ('unexpected', 15049),
#  ('unevenly', 15048),
#  ('uneven', 15047),
#  ('unequivocally', 15046),
#  ('unequivocal', 15045),
#  ('unequal', 15044),
#  ('unentrapped', 15043),
#  ('unemulsified', 15042),
#  ('uneconomical', 15041),
#  ('uneconomic', 15040),
#  ('undue', 15039),
#  ('undrilled', 15038),
#  ('undrillable', 15037),
#  ('undried', 15036),
#  ('undrained', 15035),
#  ('undoubtedly', 15034),
#  ('undisturbed', 15033),
#  ('undissolved', 15032),
#  ('undiscovered', 15031),
#  ('undeveloped', 15030),
#  ('undetected', 15029),
#  ('undetectable', 15028),
#  ('undesired', 15027),
#  ('undesirable', 15026),
#  ('underwent', 15025),
#  ('underway', 15024),
#  ('underwater', 15023),
#  ('underutilized', 15022),
#  ('undertakes', 15021),
#  ('undertaken', 15020),
#  ('undertake', 15019),
#  ('understood', 15018),
#  ('understates', 15017),
#  ('understanding', 15016),
#  ('understandable', 15015),
#  ('understand', 15014),
#  ('undersecretary', 15013),
#  ('underscores', 15012),
#  ('undersaturated', 15011),
#  ('underpressured', 15010),
#  ('underprediction', 15009),
#  ('underpredicted', 15008),
#  ('underpin', 15007),
#  ('underperforms', 15006),
#  ('underperformance', 15005),
#  ('underperform', 15004),
#  ('undermines', 15003),
#  ('undermine', 15002),
#  ('underlying', 15001),
#  ('underlining', 15000),
#  ('underlined', 14999),
#  ('underlies', 14998),
#  ('underlie', 14997),
#  ('underlain', 14996),
#  ('underground', 14995),
#  ('undergraduates', 14994),
#  ('undergraduate', 14993),
#  ('undergone', 14992),
#  ('undergoing', 14991),
#  ('undergoes', 14990),
#  ('undergo', 14989),
#  ('undergirds', 14988),
#  ('underexposed', 14987),
#  ('underexplored', 14986),
#  ('underestimation', 14985),
#  ('underestimating', 14984),
#  ('underestimates', 14983),
#  ('underestimated', 14982),
#  ('underestimate', 14981),
#  ('underdeveloped', 14980),
#  ...]

# %%
vectorizer.vocabulary_
# Out:
# {'acid': 780,
#  'stimulation': 13713,
#  'commonly': 3059,
#  'used': 15227,
#  'carbonate': 2430,
#  'reservoirs': 12247,
#  'either': 4931,
#  'matrix': 8846,
#  'acidizing': 787,
#  'fracturing': 6106,
#  'treatments': 14739,
#  'wormholes': 15807,
#  'form': 6021,
#  'wormholing': 15808,
#  'favorable': 5698,
#  'damaged': 3828,
#  'region': 12037,
#  'bypassed': 2276,
#  'desired': 4152,
#  'increase': 7326,
#  'fluid': 5949,
#  'loss': 8584,
#  'limit': 8417,
#  'conductive': 3253,
#  'fracture': 6101,
#  'length': 8337,
#  'three': 14480,
#  'major': 8706,
#  'processes': 11360,
#  'involved': 7771,
#  'convection': 3474,
#  'diffusion': 4328,
#  'surface': 14031,
#  'reaction': 11805,
#  'thorough': 14467,
#  'understanding': 15016,
#  'necessary': 9713,
#  'engineering': 5116,
#  'design': 4144,
#  'paper': 10461,
#  'fundamentally': 6196,
#  'explore': 5538,
#  'mechanisms': 8934,
#  'starting': 13631,
#  'pore': 11054,
#  'growth': 6560,
#  'wormhole': 15806,
#  'forms': 6040,
#  'larger': 8226,
#  'pores': 11057,
#  'grow': 6556,
#  'cross': 3680,
#  'sectional': 12829,
#  'area': 1407,
#  'rate': 11765,
#  'greatly': 6521,
#  'exceeds': 5412,
#  'smaller': 13289,
#  'due': 4770,
#  'happens': 6663,
#  'follows': 5990,
#  'particular': 10527,
#  'mechanism': 8933,
#  'discussed': 4458,
#  'developed': 4214,
#  'model': 9308,
#  'predict': 11200,
#  'behavior': 1835,
#  'uses': 15233,
#  'mode': 9307,
#  'size': 13215,
#  'distribution': 4556,
#  'appears': 1343,
#  'frequently': 6136,
#  'controlling': 3466,
#  'velocity': 15350,
#  'inside': 7509,
#  'make': 8711,
#  'much': 9498,
#  'faster': 5682,
#  'thus': 14495,
#  'reaching': 11800,
#  'condition': 3239,
#  'also': 1130,
#  'results': 12320,
#  'balance': 1718,
#  'overall': 10320,
#  'rock': 12487,
#  'flow': 5928,
#  'engineers': 5117,
#  'select': 12876,
#  'proper': 11467,
#  'treatment': 14738,
#  'fluids': 5950,
#  'pumping': 11591,
#  'downhole': 4674,
#  'temperature': 14280,
#  'data': 3852,
#  'obtained': 10032,
#  'logging': 8540,
#  'fiber': 5776,
#  'optic': 10193,
#  'cables': 2319,
#  'evaluate': 5353,
#  'post': 11106,
#  'performance': 10688,
#  'horizontal': 6918,
#  'wells': 15659,
#  'multiple': 9542,
#  'fractures': 6104,
#  'field': 5784,
#  'cases': 2478,
#  'qualitatively': 11656,
#  'show': 13080,
#  'capabilities': 2402,
#  'detecting': 4182,
#  'creation': 3650,
#  'transverse': 14721,
#  'poor': 11044,
#  'zonal': 15929,
#  'isolation': 7840,
#  'inflow': 7425,
#  'locations': 8526,
#  'although': 1146,
#  'fully': 6183,
#  'understood': 15018,
#  'theoretical': 14392,
#  'modeling': 9312,
#  'perspective': 10737,
#  'study': 13827,
#  'present': 11254,
#  'comprehensive': 3158,
#  'numerical': 9984,
#  'thermal': 14407,
#  'models': 9316,
#  'well': 15648,
#  'experiences': 5508,
#  'single': 13186,
#  'phase': 10792,
#  'water': 15574,
#  'injection': 7480,
#  'shut': 13092,
#  'gas': 6242,
#  'two': 14871,
#  'production': 11377,
#  'formulated': 6046,
#  'reservoir': 12246,
#  'wellbore': 15650,
#  'domains': 4632,
#  'consideration': 3336,
#  'coupling': 3601,
#  '3d': 459,
#  'space': 13441,
#  'using': 15235,
#  'mass': 8819,
#  'conservation': 3327,
#  'component': 3144,
#  'energy': 5105,
#  'darcy': 3846,
#  'law': 8259,
#  'transient': 14692,
#  'conditions': 3245,
#  '1d': 263,
#  'combined': 3026,
#  'momentum': 9367,
#  'total': 14617,
#  'sandface': 12646,
#  'profiles': 11391,
#  'solutions': 13373,
#  'enable': 5061,
#  'us': 15219,
#  'simulate': 13171,
#  'operations': 10177,
#  'multistage': 9557,
#  'occur': 10049,
#  'alternately': 1138,
#  'stage': 13597,
#  'toe': 14558,
#  'heel': 6739,
#  'example': 5405,
#  'simulates': 13173,
#  'shows': 13086,
#  'injected': 7478,
#  'makes': 8714,
#  'lower': 8595,
#  'geothermal': 6363,
#  'even': 5368,
#  'month': 9407,
#  'affects': 950,
#  'interpretation': 7665,
#  'initial': 7460,
#  'different': 4307,
#  'assumed': 1540,
#  'studies': 13826,
#  'published': 11575,
#  'previously': 11303,
#  'synthetic': 14147,
#  'case': 2476,
#  'five': 5876,
#  'demonstrates': 4050,
#  'detection': 4183,
#  'created': 3647,
#  'profile': 11390,
#  'addition': 852,
#  'apply': 1353,
#  'distributed': 4553,
#  'sensor': 12913,
#  'dts': 4761,
#  'warmback': 15546,
#  'hydraulic': 7001,
#  '30': 402,
#  'days': 3871,
#  'start': 13629,
#  'good': 6448,
#  'match': 8827,
#  'indicates': 7358,
#  'approach': 1364,
#  'estimate': 5301,
#  'individual': 7373,
#  'perforation': 10684,
#  'clusters': 2887,
#  'illustrate': 7141,
#  'qualitative': 11655,
#  'interpretations': 7667,
#  'situations': 13208,
#  'occurring': 10056,
#  'fields': 5787,
#  'warm': 15545,
#  'period': 10699,
#  'provides': 11524,
#  'insights': 7512,
#  'performed': 10691,
#  'current': 3756,
#  'time': 14519,
#  'discusses': 4459,
#  'validity': 15279,
#  'assumptions': 1544,
#  'made': 8673,
#  'previous': 11301,
#  'precautions': 11169,
#  'relevant': 12099,
#  'jetting': 7915,
#  'method': 9020,
#  'observed': 10023,
#  'positive': 11094,
#  'enhancement': 5122,
#  'extended': 5571,
#  'reach': 11797,
#  'process': 11358,
#  'reactive': 11812,
#  'chemical': 2707,
#  'solution': 13372,
#  'high': 6812,
#  'specific': 13478,
#  'entry': 5190,
#  'points': 10987,
#  'via': 15393,
#  'relatively': 12085,
#  'nozzles': 9960,
#  'designed': 4146,
#  'turbulent': 14848,
#  'jet': 7912,
#  'impinges': 7213,
#  'porous': 11071,
#  'leading': 8295,
#  'dissolution': 4526,
#  'structure': 13818,
#  'great': 6518,
#  'interest': 7619,
#  'determines': 4198,
#  'quality': 11659,
#  'job': 7923,
#  'correlates': 3550,
#  'directly': 4393,
#  'productivity': 11382,
#  'work': 15782,
#  'second': 12822,
#  'step': 13687,
#  'project': 11419,
#  'successful': 13916,
#  'formations': 6031,
#  'first': 5858,
#  'experimental': 5511,
#  'linear': 8431,
#  'core': 3522,
#  'flood': 5919,
#  'setup': 12966,
#  'including': 7300,
#  'nozzle': 9959,
#  'objective': 10005,
#  'understand': 15014,
#  'cores': 3528,
#  'identify': 7105,
#  'important': 7235,
#  'parameters': 10494,
#  'outcome': 10290,
#  'aims': 1024,
#  'describing': 4135,
#  'mathematical': 8838,
#  'standpoint': 13621,
#  'validation': 15277,
#  'improvement': 7254,
#  'tools': 14583,
#  'laboratory': 8169,
#  'experiments': 5516,
#  'revealed': 12364,
#  'recurring': 11942,
#  'large': 8224,
#  'impingement': 7212,
#  'location': 8525,
#  'shape': 13006,
#  'cavity': 2534,
#  'depending': 4083,
#  'propagation': 11457,
#  'scale': 12703,
#  'computational': 3180,
#  'dynamics': 4806,
#  'dimensional': 4358,
#  'alternates': 1139,
#  'fundamental': 6195,
#  'aspects': 1493,
#  'firstly': 5859,
#  'mechanics': 8931,
#  'exiting': 5474,
#  'continuously': 3428,
#  'impinging': 7214,
#  'media': 8941,
#  'implemented': 7220,
#  'finite': 5846,
#  'volume': 15485,
#  'solver': 13381,
#  'eddy': 4870,
#  'simulations': 13176,
#  'les': 8344,
#  'smagorinsky': 13287,
#  'lilly': 8413,
#  'sub': 13837,
#  'grid': 6532,
#  'solve': 13376,
#  'navier': 9693,
#  'stokes': 13729,
#  'continuity': 3426,
#  'equations': 5229,
#  'simulation': 13175,
#  'include': 7297,
#  'pressure': 11272,
#  'secondly': 12824,
#  'irreversible': 7817,
#  'transport': 14713,
#  'modeled': 9310,
#  'conventional': 3479,
#  'kinetics': 8070,
#  'calcite': 2336,
#  'hydrochloric': 7007,
#  'successfully': 13917,
#  'replicates': 12186,
#  'observations': 10021,
#  'coupled': 3599,
#  'represent': 12194,
#  'entire': 5175,
#  'tool': 14580,
#  'build': 2217,
#  'upscaling': 15191,
#  'integrated': 7564,
#  'dynamic': 4802,
#  'lead': 8291,
#  'establishment': 5297,
#  'standard': 13612,
#  'predicting': 11204,
#  'improving': 7258,
#  'applications': 1350,
#  'possible': 11104,
#  'mainly': 8698,
#  'penetration': 10654,
#  'surfaces': 14033,
#  'etched': 5315,
#  'width': 15712,
#  'variable': 15309,
#  'combinations': 3023,
#  'produce': 11368,
#  'significant': 13123,
#  'difference': 4305,
#  'better': 1908,
#  'reliable': 12102,
#  'simulating': 13174,
#  'weak': 15609,
#  'acids': 788,
#  'dolomite': 4627,
#  'reactivity': 11813,
#  'requires': 12226,
#  'inclusion': 7301,
#  'heat': 6726,
#  'transfer': 14681,
#  'provided': 11521,
#  'couples': 3600,
#  'factors': 5643,
#  'propagate': 11453,
#  'finally': 5823,
#  'obtain': 10030,
#  'conductivity': 3255,
#  'along': 1123,
#  'updates': 15176,
#  'domain': 4631,
#  'equation': 5228,
#  'solved': 13377,
#  'calculated': 2341,
#  'iterative': 7877,
#  'procedure': 11353,
#  'dependent': 4082,
#  'kinetic': 8069,
#  'stopped': 13734,
#  'converge': 3483,
#  'stops': 13736,
#  'etching': 5317,
#  'updated': 15175,
#  'closes': 2869,
#  'final': 5821,
#  'drawn': 4708,
#  'correlation': 3552,
#  'considers': 3340,
#  'formation': 6029,
#  'heterogeneity': 6788,
#  'compared': 3084,
#  'assuming': 1542,
#  'constant': 3352,
#  'geometry': 6343,
#  'extremely': 5606,
#  'peclet': 10627,
#  'number': 9981,
#  'represents': 12203,
#  'retarded': 12332,
#  'system': 14151,
#  'drop': 4734,
#  'value': 15287,
#  'zero': 15910,
#  'tip': 14534,
#  'theoretically': 14393,
#  'obtainable': 10031,
#  'numbers': 9982,
#  'shown': 13085,
#  'sharply': 13021,
#  'declining': 3930,
#  'towards': 14629,
#  'end': 5081,
#  'contrast': 3447,
#  'non': 9841,
#  'uniform': 15070,
#  'moderate': 9317,
#  'always': 1154,
#  'overestimates': 10345,
#  'distance': 4532,
#  'sensitive': 12909,
#  'especially': 5284,
#  'maximum': 8871,
#  'occurs': 10057,
#  'away': 1663,
#  'entrance': 5183,
#  'increases': 7328,
#  'cooling': 3511,
#  'effects': 4898,
#  'pad': 10430,
#  'limited': 8421,
#  'average': 1644,
#  'efficient': 4906,
#  'inaccurate': 7269,
#  'quantifies': 11664,
#  'integrating': 7566,
#  'propagating': 11456,
#  'pattern': 10566,
#  'expected': 5493,
#  'log': 8534,
#  'part': 10516,
#  'package': 10420,
#  'industry': 7388,
#  'many': 8770,
#  'years': 15878,
#  'recent': 11873,
#  'developments': 4220,
#  'sensing': 12908,
#  'technology': 14266,
#  'introduced': 7714,
#  'continuous': 3427,
#  'measurement': 8923,
#  'temporally': 14287,
#  'spatially': 13463,
#  'diagnosis': 4265,
#  'one': 10136,
#  'powerful': 11134,
#  'measurements': 8924,
#  'diagnose': 4261,
#  'available': 1642,
#  'information': 7436,
#  'helps': 6765,
#  'happened': 6662,
#  'problems': 11350,
#  'execution': 5447,
#  'improve': 7252,
#  'efficiency': 4905,
#  'key': 8035,
#  'built': 2225,
#  'completion': 3125,
#  'components': 3145,
#  'linked': 8450,
#  'boundary': 2087,
#  'numerically': 9985,
#  'analytical': 1222,
#  'semianalytical': 12892,
#  'preferred': 11226,
#  'correctly': 3544,
#  'appropriate': 1368,
#  'leak': 8297,
#  'description': 4136,
#  'buildup': 2223,
#  'problem': 11348,
#  'fractured': 6103,
#  'streamline': 13774,
#  'methods': 9025,
#  'compares': 3085,
#  'advantages': 921,
#  'eagle': 4821,
#  'ford': 6005,
#  'marcellus': 8779,
#  'shale': 12999,
#  'presented': 11259,
#  'generate': 6299,
#  'mineralogy': 9186,
#  'affect': 947,
#  'optimal': 10198,
#  'extensive': 5579,
#  'research': 12235,
#  'done': 4646,
#  'limestone': 8415,
#  'however': 6945,
#  'reported': 12190,
#  'rocks': 12489,
#  'presents': 11262,
#  'samples': 12639,
#  'cut': 3777,
#  'block': 2008,
#  'silurian': 13147,
#  'thornton': 14466,
#  'quarry': 11672,
#  'illinois': 7138,
#  'drilled': 4716,
#  'dimensions': 4362,
#  'diameter': 4274,
#  'long': 8552,
#  'measured': 8922,
#  'ensure': 5158,
#  'lithology': 8479,
#  'studied': 13825,
#  'test': 14336,
#  '99': 653,
#  'mineral': 9181,
#  'effectiveness': 4897,
#  'coreflood': 3524,
#  '15': 119,
#  'wt': 15835,
#  'hcl': 6714,
#  'temperatures': 14281,
#  '122': 82,
#  '185': 163,
#  '260': 369,
#  'relationships': 12083,
#  'generated': 6300,
#  'determined': 4197,
#  'respectively': 12289,
#  'patterns': 10567,
#  'experiment': 5510,
#  'found': 6064,
#  'ct': 3723,
#  'scanning': 12714,
#  'interstitial': 7689,
#  'increasing': 7329,
#  'significantly': 13124,
#  'interestingly': 7622,
#  'unlike': 15100,
#  'corresponding': 3559,
#  'breakthrough': 2134,
#  'decreases': 3951,
#  'slightly': 13251,
#  'needed': 9722,
#  'based': 1768,
#  'application': 1349,
#  'scheme': 12742,
#  'varying': 15326,
#  'references': 11986,
#  'optimistic': 10204,
#  'initially': 7465,
#  'promote': 11440,
#  'damage': 3827,
#  'removal': 12140,
#  'means': 8915,
#  'strategically': 13762,
#  'located': 8523,
#  'potential': 11120,
#  'place': 10898,
#  'injecting': 7479,
#  'need': 9721,
#  'may': 8873,
#  'enhance': 5120,
#  'hypotheses': 7065,
#  'currently': 3757,
#  'investigated': 7752,
#  'conducted': 3250,
#  'investigate': 7751,
#  'effect': 4893,
#  'equivalent': 5244,
#  'flux': 5962,
#  'standoff': 13619,
#  'maintained': 8701,
#  'low': 8594,
#  'effectively': 4896,
#  'removes': 12143,
#  'mud': 9499,
#  'filter': 5813,
#  'cake': 2333,
#  'mechanical': 8929,
#  'actions': 816,
#  'creates': 3648,
#  'combination': 3022,
#  'stimulates': 13711,
#  'without': 15756,
#  'increased': 7327,
#  'changed': 2655,
#  'isolated': 7838,
#  'local': 8512,
#  'compact': 3072,
#  'entries': 5188,
#  'followed': 5988,
#  'known': 8096,
#  'sensitivity': 12912,
#  'carried': 2460,
#  'various': 15323,
#  'indiana': 7355,
#  'winterset': 15739,
#  'weight': 15636,
#  'ambient': 1163,
#  '16': 133,
#  'velocities': 15349,
#  'fluxes': 5963,
#  'considered': 3338,
#  'heterogeneous': 6789,
#  'higher': 6813,
#  'porosity': 11069,
#  'permeability': 10713,
#  'indicate': 7356,
#  'trend': 14748,
#  'regarding': 12027,
#  'cavities': 2533,
#  'critical': 3672,
#  'tends': 14296,
#  'create': 3646,
#  'highlight': 6816,
#  'importance': 7234,
#  'physical': 10829,
#  'jobs': 7925,
#  'result': 12316,
#  'liner': 8439,
#  'completions': 3126,
#  'causing': 2525,
#  'streams': 13777,
#  'impinge': 7211,
#  'wall': 15528,
#  'differs': 4320,
#  'causes': 2524,
#  'formed': 6034,
#  'contact': 3387,
#  'forming': 6039,
#  'beyond': 1914,
#  'effective': 4895,
#  'technique': 14258,
#  'placing': 10904,
#  'laterals': 8248,
#  'removing': 12144,
#  'enhancing': 5125,
#  'penetrate': 10650,
#  'back': 1687,
#  'annular': 1277,
#  'types': 14878,
#  'highly': 6820,
#  'differences': 4306,
#  'obvious': 10038,
#  'rates': 11767,
#  'intention': 7591,
#  'quantifying': 11666,
#  'determining': 4200,
#  'concentration': 3200,
#  'respect': 12286,
#  'baseline': 1771,
#  'room': 12507,
#  'md': 8905,
#  'individually': 7374,
#  'run': 12568,
#  '180': 155,
#  '28': 382,
#  '60': 544,
#  '140': 107,
#  'changing': 2657,
#  'orifice': 10249,
#  'stream': 13772,
#  'exits': 5475,
#  'direct': 4385,
#  'comparison': 3088,
#  'eliminating': 4981,
#  'dispersion': 4486,
#  'point': 10984,
#  'heightened': 6748,
#  'happen': 6661,
#  'would': 15817,
#  'pronounced': 11450,
#  'raised': 11729,
#  'tapers': 14210,
#  'progressively': 11415,
#  'recently': 11874,
#  'anisotropic': 1266,
#  'networks': 9757,
#  'arise': 1423,
#  'carbonates': 2432,
#  'openhole': 10163,
#  'cased': 2477,
#  'densely': 4064,
#  'perforated': 10682,
#  'isotropic': 7856,
#  'network': 9755,
#  'radial': 11706,
#  'around': 1440,
#  'actual': 829,
#  'stimulated': 13710,
#  'elliptical': 4988,
#  'analogously': 1210,
#  'spherical': 13513,
#  'actually': 830,
#  'ellipsoidal': 4985,
#  'impact': 7181,
#  'taken': 14185,
#  'account': 746,
#  'designing': 4147,
#  'use': 15226,
#  'coverage': 3615,
#  'longer': 8554,
#  'partial': 10517,
#  'skin': 13228,
#  'factor': 5638,
#  'impairing': 7188,
#  'estimating': 5304,
#  'main': 8696,
#  'topics': 14588,
#  'analyzed': 1226,
#  'anisotropy': 1269,
#  'applied': 1351,
#  'resulting': 12319,
#  'scenario': 12730,
#  'averaged': 1645,
#  'continuum': 3429,
#  'validated': 15274,
#  'analysis': 1218,
#  'regions': 12039,
#  'acidized': 786,
#  'equally': 5224,
#  'sized': 13217,
#  'hence': 6769,
#  'like': 8407,
#  'hawkins': 6701,
#  'formula': 6042,
#  'proposed': 11478,
#  'instead': 7532,
#  'specifically': 13479,
#  'type': 14877,
#  'optimum': 10213,
#  '70': 581,
#  'density': 4067,
#  'required': 12223,
#  'given': 6395,
#  'depends': 4084,
#  'strongly': 13814,
#  'obtaining': 10033,
#  'creating': 3649,
#  'opening': 10164,
#  'existing': 5471,
#  'natural': 9687,
#  'flows': 5941,
#  'intersecting': 7684,
#  'etches': 5316,
#  'walls': 15532,
#  'generates': 6301,
#  'hand': 6645,
#  'existence': 5470,
#  'reduces': 11970,
#  'less': 8345,
#  'reacts': 11816,
#  'order': 10225,
#  'accurately': 764,
#  'naturally': 9689,
#  'calculating': 2343,
#  'assumes': 1541,
#  'intersected': 7683,
#  'symmetric': 14118,
#  'leakoff': 8302,
#  'calculation': 2344,
#  'takes': 14187,
#  'small': 13288,
#  'heterogeneities': 6787,
#  'strong': 13811,
#  'function': 6185,
#  'play': 10936,
#  'role': 12497,
#  'defining': 3978,
#  'position': 11090,
#  'resultant': 12317,
#  'prediction': 11205,
#  'feasibility': 5730,
#  'classification': 2817,
#  'typically': 14880,
#  'considerable': 3334,
#  'amount': 1190,
#  'usually': 15237,
#  'depth': 4112,
#  'resolution': 12273,
#  'target': 14216,
#  'interval': 7690,
#  'tight': 14507,
#  'essential': 5290,
#  'take': 14184,
#  'petrophysical': 10773,
#  'compositional': 3149,
#  'elastic': 4937,
#  'properties': 11469,
#  'estimates': 5303,
#  'selection': 12879,
#  'candidate': 2389,
#  'zones': 15932,
#  'northern': 9931,
#  'slope': 13261,
#  'tazhong': 14231,
#  'uplift': 15184,
#  'tarim': 14221,
#  'basin': 1779,
#  'china': 2731,
#  'perform': 10686,
#  'multi': 9514,
#  'volumetric': 15487,
#  'concentrations': 3201,
#  'minerals': 9187,
#  'saturations': 12680,
#  'since': 13182,
#  'shear': 13024,
#  'wave': 15588,
#  'sonic': 13395,
#  'logs': 8549,
#  'moduli': 9337,
#  'medium': 8948,
#  'self': 12885,
#  'consistent': 3344,
#  'approximation': 1375,
#  'differential': 4309,
#  'theory': 14395,
#  'corrections': 3542,
#  'biot': 1974,
#  'gassmann': 6255,
#  'substitution': 13898,
#  'inputs': 7499,
#  'bulk': 2226,
#  'inclusions': 7302,
#  'grains': 6493,
#  'validating': 15276,
#  'accordingly': 745,
#  'unsupervised': 15161,
#  'neural': 9760,
#  'derived': 4121,
#  'estimated': 5302,
#  'intervals': 7691,
#  'variogram': 15322,
#  'lengths': 8339,
#  'challenging': 2643,
#  'agreement': 1006,
#  'identified': 7103,
#  'classes': 2813,
#  'verified': 15367,
#  'thin': 14442,
#  'sections': 12830,
#  'relative': 12084,
#  'errors': 5266,
#  'approximately': 1372,
#  '13': 87,
#  'compare': 3083,
#  'input': 7498,
#  'improved': 7253,
#  'success': 13914,
#  'gives': 6396,
#  'insight': 7510,
#  'evaluation': 5357,
#  'best': 1903,
#  'acoustic': 793,
#  'das': 3848,
#  'emerging': 5018,
#  'heralded': 6775,
#  'interrogation': 7677,
#  'operation': 10175,
#  'challenge': 2640,
#  'come': 3032,
#  'processing': 11362,
#  'vast': 15331,
#  'amounts': 1192,
#  'produced': 11369,
#  'originally': 10252,
#  'sound': 13423,
#  'amplitude': 1200,
#  'defined': 3976,
#  'translated': 14701,
#  'frequency': 6134,
#  'characteristics': 2671,
#  'related': 12076,
#  'mostly': 9437,
#  'today': 14553,
#  'started': 13630,
#  'building': 2220,
#  'simulator': 13177,
#  'lab': 8160,
#  'flowing': 5934,
#  'nitrogen': 9817,
#  'parallel': 10474,
#  'plate': 10925,
#  'cell': 2565,
#  'proppant': 11482,
#  'packs': 10429,
#  'permeabilities': 10712,
#  'section': 12828,
#  'connected': 3309,
#  'collected': 2992,
#  'array': 1447,
#  'microphones': 9110,
#  'simulated': 13172,
#  'directional': 4389,
#  'hydrophone': 7034,
#  'characteristic': 2670,
#  'signal': 13117,
#  'raw': 11783,
#  'fast': 5681,
#  'fourier': 6070,
#  'transform': 14686,
#  'relationship': 12082,
#  'level': 8355,
#  'observation': 10019,
#  'consisting': 3346,
#  'pipe': 10871,
#  'signals': 13118,
#  'subdivided': 13845,
#  'parts': 10541,
#  'pack': 10419,
#  'near': 9706,
#  'described': 4133,
#  'set': 12954,
#  'particles': 10525,
#  'allows': 1117,
#  'analogy': 1214,
#  'assume': 1539,
#  'steady': 13663,
#  'state': 13634,
#  'noise': 9834,
#  'center': 2582,
#  'packing': 10427,
#  'mesh': 8987,
#  'complex': 3127,
#  'structures': 13820,
#  'incompressible': 7313,
#  'compressible': 3165,
#  'allow': 1112,
#  'inlet': 7489,
#  'induced': 7378,
#  '10': 43,
#  'seconds': 12826,
#  'collect': 2991,
#  'enough': 5144,
#  'peaks': 10620,
#  'plot': 10949,
#  'respond': 12290,
#  'oil': 10106,
#  'dissolve': 4528,
#  'permeable': 10715,
#  'channels': 2662,
#  'called': 2361,
#  'deepest': 3960,
#  'measuring': 8926,
#  'volumes': 15486,
#  'exit': 5473,
#  'normalized': 9921,
#  'calcium': 2338,
#  'caco3': 2323,
#  'carbon': 2428,
#  'dioxide': 4374,
#  'co2': 2906,
#  '000': 1,
#  'psi': 11556,
#  'backpressure': 1693,
#  'keep': 8015,
#  'basis': 1781,
#  'solubility': 13366,
#  'undissolved': 15032,
#  'gaseous': 6244,
#  ...}

# %%
new_stopwords = ['commonly', 'used', 'either', ]
